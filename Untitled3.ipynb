# %%
import os
os.chdir(r"C:\Users\kulra\OneDrive\Desktop\SplittedPDF\35238 letters")
os.getcwd()
# Out:
# 'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters'

# %%
# importing required modules
import PyPDF2
 
# creating a pdf file object
pdfFileObj = open(r'C:\Users\kulra\OneDrive\Desktop\SplittedPDF\35238 letters\35238 letters-23.pdf', 'rb')
 
# creating a pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
 
# printing number of pages in pdf file
print(pdfReader.numPages)
 
# creating a page object
pageObj = pdfReader.getPage(0)
 
# extracting text from page
print(pageObj.extractText())
var1=pageObj.extractText()
 
# closing the pdf file object
pdfFileObj.close()
# Out:
# 1
# F
# orm 80
# 04
#
#
#
# Global Atlantic
#
# Financial Group
#
# P.O. Box 305030, Nashville, TN 37230
# -
# 5030
#
# Customer Contact Center
#
# Tel: 877 462 8992 Fax: 800 351 0603
#
#
#
# 4/1/2022
#
#
#
#
#
# LORRAINE TULLY
#
# 3455 PINEMONT DRIVE
#
# DOUGLASVILLE, GA 30135
#
#
#
#
# Agent Code:
# 000011
# 3629
#
# RE:
#
# Contract
# Reinstatement
#
#
# Dear
#
# LORRAINE
#
# TULLY
# :
#
#
# This is a confirmation
#
# that you have been reinstated with Global Atlantic Financial Group effective on
# 3/23/2022
#
# with the profile code of
#
# 001
# .
#
#
# Yo
# u
# may
#
# ask follow up questions by
# f
# ax, e
# mail, regular mail or phone at these addresses:
#
#
#
# F
# ax: 800
# -
# 351
# -
# 0603
#
#
#
# E
# mail:  contracting@gafg.com
#
#
#
# Regular Mail Addr
# ess: PO Box 305030,
#
# Nashville, TN 37230
#
#
#
# Phone: 877
# -
# 462
# -
# 8992
#
#
#
# Sincerely,
#
#
# Agency Services

# %%
var1
test_list=var1.split("\n")
print(type(test_list))
for element in range(len(test_list)):
    #test_list[element].remove("")
    test_list[element].strip()
# Out:
# <class 'list'>

# %%
test_list
# Out:
# ['F',
#  'orm 80',
#  '04',
#  ' ',
#  ' ',
#  ' ',
#  'Global Atlantic',
#  ' ',
#  'Financial Group',
#  ' ',
#  'P.O. Box 305030, Nashville, TN 37230',
#  '-',
#  '5030',
#  ' ',
#  'Customer Contact Center ',
#  ' ',
#  'Tel: 877 462 8992 Fax: 800 351 0603',
#  ' ',
#  ' ',
#  ' ',
#  '4/1/2022',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'LORRAINE TULLY',
#  ' ',
#  '3455 PINEMONT DRIVE',
#  ' ',
#  'DOUGLASVILLE, GA 30135',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Agent Code:  ',
#  '000011',
#  '3629',
#  ' ',
#  'RE:',
#  ' ',
#  'Contract ',
#  'Reinstatement',
#  ' ',
#  ' ',
#  'Dear',
#  ' ',
#  'LORRAINE',
#  ' ',
#  'TULLY',
#  ':',
#  ' ',
#  ' ',
#  'This is a confirmation',
#  ' ',
#  'that you have been reinstated with Global Atlantic Financial Group effective on ',
#  '3/23/2022',
#  ' ',
#  'with the profile code of',
#  ' ',
#  '001',
#  '.',
#  ' ',
#  ' ',
#  'Yo',
#  'u ',
#  'may',
#  ' ',
#  'ask follow up questions by ',
#  'f',
#  'ax, e',
#  'mail, regular mail or phone at these addresses:',
#  ' ',
#  '',
#  ' ',
#  'F',
#  'ax: 800',
#  '-',
#  '351',
#  '-',
#  '0603',
#  ' ',
#  '',
#  ' ',
#  'E',
#  'mail:  contracting@gafg.com',
#  ' ',
#  '',
#  ' ',
#  'Regular Mail Addr',
#  'ess: PO Box 305030,',
#  ' ',
#  'Nashville, TN 37230',
#  ' ',
#  '',
#  ' ',
#  'Phone: 877',
#  '-',
#  '462',
#  '-',
#  '8992',
#  ' ',
#  ' ',
#  ' ',
#  'Sincerely,',
#  ' ',
#  ' ',
#  'Agency Services',
#  ' ',
#  ' ',
#  '']

# %%
def findAgentCodeInNextLine(test_list):
    for element in range(len(test_list)):
        if (test_list[element].strip() == "Agent Code:"):
             AgentCode=test_list[element+1]
    return AgentCode
findAgentCodeInNextLine(test_list)
# Out:
# '0000002344'

# %%
from os import chdir, listdir
from os.path import isfile, join, exists, isdir
import camelot

# print("\\".join((r"C:\kdata\myPYTHON\Python_Courses\Python_March2022_Tutorials\Day9\Generators", "entry.py")))
# print(os.getcwd())
# new_file_name = join(r"C:\kdata\myPYTHON\Python_Courses\Python_March2022_Tutorials\Day9\Generators", "entry.py")
# print(new_file_name)


def get_files(path):
    for file in listdir(path):
        full_path = join(path, file)
        if isfile(full_path):
            if exists(full_path):
                yield full_path


def get_directories(path):
    for directory in listdir(path):
        full_path = join(path, directory)
        if isdir(full_path):
            if exists(full_path):
                yield full_path


# def get_files_recursively(directory):
#     for file in get_files(directory):
#         yield file
#     for subdirectory in get_directories(directory):
#         for file in get_files_recursively(subdirectory):
#             yield file

# simplified version of above function


def get_files_recursively(directory):
    yield from get_files(directory)
    for subdirectory in get_directories(directory):
        yield from get_files_recursively(subdirectory)


files = get_files_recursively(r"C:\Users\kulra\OneDrive\Desktop\SplittedPDF\35238 letters")

#for file_names in files:
#   print(file_names)

file=list(files)

#print(type(files))
print(len(file))

def convert(lit): 
    res_dct={lit[i]:"" for i in range(len(lit))}

    #res_dct={lit[i]:i for i in range(len(lit))}
    return res_dct
def convert2(lit): 
    #res_dct={lit[i]:"" for i in range(len(lit))}

    res_dct={lit[i]:i for i in range(len(lit))}
    return res_dct

#cdict={file:range(len(file))}

#filesInDictionaryString=convert(file)
filesInDictionaryNumber=convert2(file)

#for c in cdict:
#    print (c)

#print(filesInDictionaryString)
#print(filesInDictionaryNumber)

chdir(r"C:\Users\kulra\OneDrive\Desktop\SplittedPDF\35238 letters")
fileDictionary={}
print(dir)
# Out:
# 38
# <built-in function dir>

# %% [raw]
# for value in filesInDictionaryNumber:
#     print(value)
#     # creating a pdf file object
#     pdfFileObj = open(value, 'rb')
#
#     # creating a pdf reader object
#     pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
#
#     # printing number of pages in pdf file
#     #print(pdfReader.numPages)
#
#     # creating a page object
#     pageObj = pdfReader.getPage(0)
#
#     # extracting text from page
#     #print(pageObj.extractText())
#     var1=pageObj.extractText()
#     test_list=var1.split("\n")
#
#     # closing the pdf file object
#     pdfFileObj.close()
#     filesInDictionaryNumber[value]=findAgentCodeInNextLine(test_list)
#     print(findAgentCodeInNextLine(test_list))

# %%
for value in filesInDictionaryNumber:
    print(value)
    # creating a pdf file object
    pdfFileObj = open(value, 'rb')
 
    # creating a pdf reader object
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
 
    # printing number of pages in pdf file
    #print(pdfReader.numPages)
 
    # creating a page object
    pageObj = pdfReader.getPage(0)
 
    # extracting text from page
    #print(pageObj.extractText())
    var1=pageObj.extractText()
    test_list=var1.split("\n")
   
    # closing the pdf file object
    pdfFileObj.close()
    filesInDictionaryNumber[value]=findAgentCodeInNextLine(test_list)
    print(findAgentCodeInNextLine(test_list))
# Out:
# C:\Users\kulra\OneDrive\Desktop\SplittedPDF\35238 letters\35238 letters-1.pdf
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6071064939b0> in <module>
#      20     # closing the pdf file object
#      21     pdfFileObj.close()
# ---> 22     filesInDictionaryNumber[value]=findAgentCodeInNextLine(test_list)
#      23     print(findAgentCodeInNextLine(test_list))
#
# NameError: name 'findAgentCodeInNextLine' is not defined

# %%
filesInDictionaryNumber
# Out:
# {'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-1.pdf': '0000002344',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-10.pdf': '0000101706',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-11.pdf': '0000108661',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-12.pdf': '0000109587',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-13.pdf': '0000109738',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-14.pdf': '0000110070',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-15.pdf': '0000110075',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-16.pdf': '0000110326',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-17.pdf': '0000110782',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-18.pdf': '0000111006',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-19.pdf': '0000112345',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-2.pdf': '0000002709',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-20.pdf': '0000112538',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-21.pdf': '0000112575',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-22.pdf': '0000112897',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-23.pdf': '000011',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-24.pdf': '0000114138',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-25.pdf': '0000114162',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-26.pdf': '0000114163',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-27.pdf': '0000114232',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-28.pdf': '0000114295',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-29.pdf': '0000114300',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-3.pdf': '0000004081',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-30.pdf': '0000114306',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-31.pdf': '0000114312',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-32.pdf': '0000114370',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-33.pdf': '0000114382',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-34.pdf': '0000114445',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-35.pdf': '0000114497',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-36.pdf': '0000114499',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-37.pdf': '0000114511',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-4.pdf': '0000005674',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-5.pdf': '0000010052',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-6.pdf': '0000033952',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-7.pdf': '0000042086',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-8.pdf': '0000046763',
#  'C:\\Users\\kulra\\OneDrive\\Desktop\\SplittedPDF\\35238 letters\\35238 letters-9.pdf': '0000101438'}

# %%
import pandas as pd


df = pd.DataFrame(data=filesInDictionaryNumber, index=[0])

df = (df.T)



print (df)

#df.to_excel('dict1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-483892517bb6> in <module>
#       6 #df = (df.T)
#       7
# ----> 8 print(T)
#       9
#      10 print (df)
#
# NameError: name 'T' is not defined

# %%
import PyPDF2
pdf_file = open(r'C:\Users\kulra\OneDrive\Desktop\SplittedPDF\35238 letters\35238 letters-23.pdf')
read_pdf = PyPDF2.PdfFileReader(pdf_file)
number_of_pages = read_pdf.getNumPages()
page = read_pdf.getPage(0)
page_content = page.extractText()
print(page_content)
# Out:
# PdfReadWarning: PdfFileReader stream/file object is not in binary mode. It may not be read correctly. [pdf.py:1079]
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-14-3e011eddf1bf> in <module>
#       1 import PyPDF2
#       2 pdf_file = open(r'C:\Users\kulra\OneDrive\Desktop\SplittedPDF\35238 letters\35238 letters-23.pdf')
# ----> 3 read_pdf = PyPDF2.PdfFileReader(pdf_file)
#       4 number_of_pages = read_pdf.getNumPages()
#       5 page = read_pdf.getPage(0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\PyPDF2\pdf.py in __init__(self, stream, strict, warndest, overwriteWarnings)
#    1082             stream = BytesIO(b_(fileobj.read()))
#    1083             fileobj.close()
# -> 1084         self.read(stream)
#    1085         self.stream = stream
#    1086
#
# C:\ProgramData\Anaconda3\lib\site-packages\PyPDF2\pdf.py in read(self, stream)
#    1687         if debug: print(">>read", stream)
#    1688         # start at the end:
# -> 1689         stream.seek(-1, 2)
#    1690         if not stream.tell():
#    1691             raise utils.PdfReadError('Cannot read an empty file')
#
# UnsupportedOperation: can't do nonzero end-relative seeks
